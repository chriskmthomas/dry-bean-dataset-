# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel ('drybean.xlsx')
df.head(20)
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0   28395.0    610.291       208.178117       173.888747      1.197191
# 1   28734.0    638.018       200.524796       182.734419      1.097356
# 2   29380.0    624.110       212.826130       175.931143      1.209713
# 3   30008.0    645.884       210.557999       182.516516      1.153638
# 4   30140.0    620.134       201.847882       190.279279      1.060798
# 5   30279.0    634.927       212.560556       181.510182      1.171067
# 6   30477.0    670.033       211.050155       184.039050      1.146768
# 7   30519.0    629.727       212.996755       182.737204      1.165591
# 8   30685.0    635.681       213.534145       183.157146      1.165852
# 9   30834.0    631.934       217.227813       180.897469      1.200834
# 10  30917.0    640.765       213.560089       184.439871      1.157885
# 11  31091.0    638.558       210.486255       188.326848      1.117665
# ...

# %%
df.dtypes
# Out:
# Area               float64
# Perimeter          float64
# MajorAxisLength    float64
# MinorAxisLength    float64
# AspectRation       float64
# Eccentricity       float64
# ConvexArea           int64
# EquivDiameter      float64
# Extent             float64
# Solidity           float64
# roundness          float64
# Compactness        float64
# ShapeFactor1       float64
# ShapeFactor2       float64
# ShapeFactor3       float64
# ShapeFactor4       float64
# Class               object
# dtype: object

# %%
df.columns
# Out:
# Index(['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
#        'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
#        'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
#        'ShapeFactor3', 'ShapeFactor4', 'Class'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13410.000000  13525.000000     13448.000000     13611.000000
# mean    53145.938777    855.214950       320.578938       202.270714
# std     29346.256142    214.595037        85.713797        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36461.000000    703.317000       253.587883       175.848170
# 50%     44732.500000    794.885000       297.864031       192.431733
# 75%     61493.000000    977.030000       376.813482       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13455.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     252.933374      0.749733
# std        0.246678      0.092002   29774.915817      59.104456      0.049086
# ...

# %%
df.corr()
# Out:
#                      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# Area             1.000000   0.966692         0.931748         0.951492
# Perimeter        0.966692   1.000000         0.977412         0.913580
# MajorAxisLength  0.931748   0.977412         1.000000         0.827057
# MinorAxisLength  0.951492   0.913580         0.827057         1.000000
# AspectRation     0.240210   0.384750         0.547714        -0.009161
# Eccentricity     0.266650   0.390527         0.540070         0.019574
# ConvexArea       0.999939   0.967725         0.932665         0.951339
# EquivDiameter    0.984970   0.991389         0.961890         0.948795
# Extent           0.054505  -0.020108        -0.076074         0.145957
# Solidity        -0.195218  -0.303681        -0.281449        -0.155820
# roundness       -0.356403  -0.547489        -0.594267        -0.211975
# Compactness     -0.266755  -0.406320        -0.565964        -0.015066
# ...

# %%
df['MajorAxisLength'].fillna(df['MajorAxisLength'].mode()[0], inplace=True)
df['EquivDiameter'].fillna(df['EquivDiameter'].mode()[0], inplace=True)

# %%
df['roundness'].fillna(df['roundness'].mode()[0], inplace=True)
df['Area'].fillna(df['Area'].mode()[0], inplace=True)

# %%
df.head(50)
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0   28395.0    610.291       208.178117       173.888747      1.197191
# 1   28734.0    638.018       200.524796       182.734419      1.097356
# 2   29380.0    624.110       212.826130       175.931143      1.209713
# 3   30008.0    645.884       210.557999       182.516516      1.153638
# 4   30140.0    620.134       201.847882       190.279279      1.060798
# 5   30279.0    634.927       212.560556       181.510182      1.171067
# 6   30477.0    670.033       211.050155       184.039050      1.146768
# 7   30519.0    629.727       212.996755       182.737204      1.165591
# 8   30685.0    635.681       213.534145       183.157146      1.165852
# 9   30834.0    631.934       217.227813       180.897469      1.200834
# 10  30917.0    640.765       213.560089       184.439871      1.157885
# 11  31091.0    638.558       210.486255       188.326848      1.117665
# ...

# %%
df[df==np.inf]=np.nan
df.fillna(df.mean(), inplace=True)

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#df['MajorAxisLength']=(df['MajorAxisLength'].replace('NaN',0))

# %%
#roundness = df['roundness'].mode()
#EquivDiameter = df['EquivDiameter'].mode()
#MajorAxisLength = df['MajorAxisLength'].mode()
#df['roundness']=(df['roundness'].fillna(roundness))
#df['EquivDiameter']=(df['EquivDiameter'].fillna(EquivDiameter))
#df['MajorAxisLength']=(df['MajorAxisLength'].fillna(MajorAxisLength))

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# %%
df['Class']= label_encoder.fit_transform(df['Class'])
  
df['Class'].unique()
# Out:
# array([5, 0, 1, 2, 4, 6, 3])

# %%
 df = df.astype(float)

# %%
df
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395.0    610.291       208.178117       173.888747      1.197191
# 1      28734.0    638.018       200.524796       182.734419      1.097356
# 2      29380.0    624.110       212.826130       175.931143      1.209713
# 3      30008.0    645.884       210.557999       182.516516      1.153638
# 4      30140.0    620.134       201.847882       190.279279      1.060798
# ...        ...        ...              ...              ...           ...
# 13606  42097.0    759.696       288.721612       185.944705      1.552728
# 13607  42101.0    757.499       277.368480       190.713136      1.476439
# 13608  42139.0    759.321       281.539928       191.187979      1.472582
# 13609  42147.0    763.779       283.382636       190.275731      1.489326
# 13610  42159.0    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
feature_cols = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
       'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
       'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
       'ShapeFactor3', 'ShapeFactor4']

# %%
X = df[feature_cols] # Features
y = df['Class']

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
#from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz

#import pydotplus
#import pydot
from IPython.display import Image

from IPython import display
from sklearn import datasets, utils, tree
#from sklearn.externals.six import StringIO  
from sklearn.tree import DecisionTreeClassifier

# %%
# The decision tree classifier.
clf = tree.DecisionTreeClassifier()
# Training the Decision Tree
clf_train = clf.fit(X_train,y_train)

# %%
y_pred = clf.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
# Model Accuracy, how well the model performs
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8977372906259183
